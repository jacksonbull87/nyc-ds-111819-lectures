# %% [markdown]
# ## Starting Off
#
# Think of one lingering quetion you have about SQL and sedd it to our slack class channel.

# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ## Objectives
# You will be able to:
# * Make an API call to Yelp

# %% [markdown]
# ## Agenda
#
# * Build up an API Call
# * Look at the results

# %%
import requests
import json

# %% [markdown]
# For more information about the request package you can use the following resources:
#
# **Tutorial:** https://realpython.com/python-requests/
#
# **Package Documentation:** https://requests.readthedocs.io/en/master/

# %% [markdown]
# ![](quota.png)

# %% [markdown]
# Let's do a serach of businesses on the Yelp API.

# %%
# set theurl and endpoint we want to hit
url = 'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# Now that you have an API key, let's enter set that information here so that we can do our searches. Once you have the `api_key` variable, place int in our header.

# %%
client_id = 'NTOFq0hWesFzHYCprBXMFw'
api_key = 'Gh_Hoaof6K6gvy1HxSSBhy4Y0wwwFvIPKgC00UWhvCvkeVhJStATKWD-eMbwilkXhjcdDiqCI3ZBYxfq0nV6CvpGhz4T9VPCFgLDH2B54eqTff1-a7PQd9fR7kHpXXYx'

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %% [markdown]
# We now need to determine our parameters we want to pass.
#
# You must give a specific search term, location and one other paramter to limit your search.
#
# Remember you can search the API documenation to find another parameter to limit your search.
# https://www.yelp.com/developers/documentation/v3/get_started

# %%
# what type of business do you want to search
term = 'vietnamese'

#where do you want to perform this search
location = 'brooklyn, new york'

# what is your other parameter you want to search against
params = {'attributes':'hot_and_new'}

# %%
url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'param' : params
            }

# %% [markdown]
# Now that we have all of the parts necessary for an API call, let's put them together.

# %%
response = requests.get(url, headers = headers, params = url_params)

# %% [markdown]
# ## The Response
#
# The response of a GET request often has some valuable information, known as a payload, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use `.content`
#
# You will often want to convert them into a string using a character encoding such as UTF-8. Response will do that for you when you access `.text`
#
# The response is actually serialized JSON content. To get a dictionary, you could take the str you retrieved from `.text` and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': 'rnioN9LciPxkfKo799QRCQ',
#    'alias': 'u-bar-and-restaurant-brooklyn',
#    'name': 'U Bar & Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7nfJYHonc6q1O8uG4JWvAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/u-bar-and-restaurant-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 30,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.598165, 'longitude': -73.960569},
#    'transactions': [],
#    'location': {'address1': '1114 Ave U',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11223',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1114 Ave U', 'Brooklyn, NY 11223']},
#    'phone': '+13475876843',
#    'display_phone': '(347) 587-6843',
#    'distance': 6283.193130681312},
#   {'id': 'SSDOkx5enfRH3nsniS_2jA',
#    'alias': '5ive-spice-brooklyn-3',
#    'name': '5ive Spice',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8Yz9iiKDesar5FvWQTIaTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/5ive-spice-brooklyn-3?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 606,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68145923448, 'longitude': -73.9772509779765},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '52 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17188573483',
#    'display_phone': '(718) 857-3483',
#    'distance': 4550.115551912267},
#   {'id': 'ZLZswviJ0CSX5ZeQFSO2sQ',
#    'alias': 'pho-vietnam-brooklyn',
#    'name': 'Pho Vietnam',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6UFwrMXM63jC6e6SC8o7-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pho-vietnam-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 291,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.598733, 'longitude': -73.958544},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1243 Ave U',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11229',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1243 Ave U', 'Brooklyn, NY 11229']},
#    'phone': '+17189982858',
#    'display_phone': '(718) 998-2858',
#    'distance': 6175.689435579791},
#   {'id': 'CPY7tIaJ8XaEEZ9n7xBvkw',
#    'alias': 'banh-mi-place-brooklyn',
#    'name': 'Banh Mi Place',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DFyzdg-CAUatUmROBDqB0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/banh-mi-place-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 233,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6732865, 'longitude': -73.963134},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '824B Washington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['824B Washington Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17185522660',
#    'display_phone': '(718) 552-2660',
#    'distance': 3074.1870744327484},
#   {'id': 'O-zwQQV8AExgdPoJiqjpDg',
#    'alias': 'ba-xuyen-brooklyn-2',
#    'name': 'Ba Xuyen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0ughD3xXQYDcwvuHzUdj3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ba-xuyen-brooklyn-2?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 653,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.64528, 'longitude': -73.9997099},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4222 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4222 8th Ave', 'Brooklyn, NY 11232']},
#    'phone': '+17186336601',
#    'display_phone': '(718) 633-6601',
#    'distance': 5149.22835317752},
#   {'id': 'gl9UKHI6G-JhIBjjLFOhYA',
#    'alias': 'high-lúa-vietnamese-kitchen-brooklyn',
#    'name': 'High Lúa Vietnamese Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3KwOwrOJ_DQNb6rO4ItAjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/high-l%C3%BAa-vietnamese-kitchen-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 127,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71258, 'longitude': -73.96045},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '182 S 2nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['182 S 2nd St', 'Brooklyn, NY 11211']},
#    'phone': '+13478449666',
#    'display_phone': '(347) 844-9666',
#    'distance': 6921.153948197649},
#   {'id': 'R-TRmWuK1nBGRB7iq0XphA',
#    'alias': 'nam-nam-brooklyn-2',
#    'name': 'Nam Nam',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KbrWiKfv_yD5-T5AjI-A3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nam-nam-brooklyn-2?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 441,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70728, 'longitude': -73.94509},
#    'transactions': ['pickup'],
#    'price': '$',
#    'location': {'address1': '109 Montrose Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['109 Montrose Ave', 'Brooklyn, NY 11206']},
#    'phone': '+17183029200',
#    'display_phone': '(718) 302-9200',
#    'distance': 6130.371931620766},
#   {'id': 'iYFauSnqLxvr4HTY_cIElg',
#    'alias': 'little-mo-brooklyn',
#    'name': 'Little Mo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/f2pS7K-QYKqA97dr9cBmVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-mo-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 312,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69701, 'longitude': -73.93368},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1158 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1158 Myrtle Ave', 'Brooklyn, NY 11221']},
#    'phone': '+19292108100',
#    'display_phone': '(929) 210-8100',
#    'distance': 4991.218644640781},
#   {'id': 'CMm3Xf-9v3QJ4ge20MoEVg',
#    'alias': 'pho-60-brooklyn-8',
#    'name': 'Pho 60',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CFORdDi1MVSSXrUihQN5Lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pho-60-brooklyn-8?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 175,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6328610543603,
#     'longitude': -74.0049596875906},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1001 60th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11219',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1001 60th St', 'Brooklyn, NY 11219']},
#    'phone': '+17188857722',
#    'display_phone': '(718) 885-7722',
#    'distance': 5943.045144832211},
#   {'id': 'IoPJ1I0eQn6wnrFAoqFXOw',
#    'alias': 'banhmigos-new-york-2',
#    'name': 'Banhmigos',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/loi0CTRvG34ajwyfeczieQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/banhmigos-new-york-2?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 9,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69111, 'longitude': -73.99184},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '92 Court St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['92 Court St', 'New York, NY 11201']},
#    'phone': '+19293376188',
#    'display_phone': '(929) 337-6188',
#    'distance': 6184.807526230124},
#   {'id': 'V58g7E1AHkuTchTVyLQuYQ',
#    'alias': 'saigon-grill-and-bar-brooklyn-3',
#    'name': 'Saigon Grill & Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/n0P0wybogAiDPrhsXoF0Fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saigon-grill-and-bar-brooklyn-3?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 201,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.61883, 'longitude': -73.93099},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4521 Ave N',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11234',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4521 Ave N', 'Brooklyn, NY 11234']},
#    'phone': '+17183388883',
#    'display_phone': '(718) 338-8883',
#    'distance': 3780.4561518574164},
#   {'id': 'EvLkJaWEXTZ8QNBrxOhDsA',
#    'alias': 'bunker-brooklyn',
#    'name': 'Bunker',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vM8KHLsG6Xk-z1IZLdCKmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bunker-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 712,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7105638, 'longitude': -73.9233984},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '99 Scott Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 Scott Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17183864282',
#    'display_phone': '(718) 386-4282',
#    'distance': 6613.711059246267},
#   {'id': 'rxiY-8y415P7HM68qOlJcw',
#    'alias': 'ha-noi-vietnamese-kitchen-brooklyn',
#    'name': 'Ha Noi Vietnamese Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6OJl8xYpBrJ35gLuaVf9rQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ha-noi-vietnamese-kitchen-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 269,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.66666, 'longitude': -73.9814899},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '448 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['448 9th St', 'Brooklyn, NY 11215']},
#    'phone': '+17187887755',
#    'display_phone': '(718) 788-7755',
#    'distance': 3893.44633332756},
#   {'id': '3nATnhLyWRvbUGRwK2zdXQ',
#    'alias': 'zen-yai-pho-noodle-bar-brooklyn',
#    'name': 'Zen Yai Pho Noodle Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UlahgYJ0ka9YWRSYx7UgMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zen-yai-pho-noodle-bar-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 55,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.713897, 'longitude': -73.960337},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '208 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['208 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+13478895150',
#    'display_phone': '(347) 889-5150',
#    'distance': 7067.576415905188},
#   {'id': 't4PA7TuIg2TCxBkVuRw7AA',
#    'alias': 'pho-tay-ho-brooklyn',
#    'name': 'Pho Tay Ho',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XxlImvK74ebH_NijaojNgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pho-tay-ho-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 395,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.600039, 'longitude': -73.990132},
#    'transactions': ['pickup'],
#    'price': '$',
#    'location': {'address1': '2351 86th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2351 86th St', 'Brooklyn, NY 11214']},
#    'phone': '+17184490199',
#    'display_phone': '(718) 449-0199',
#    'distance': 7221.689675413961},
#   {'id': 'FCvWw_e__UfxYusrC99Klw',
#    'alias': 'little-saigon-pearl-brooklyn',
#    'name': 'Little Saigon Pearl',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gmzHEd-bYy4AwusrWlwIbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-saigon-pearl-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 145,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.599368, 'longitude': -73.9902738},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '9 Bay 35th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Bay 35th St', 'Brooklyn, NY 11214']},
#    'phone': '+17189968808',
#    'display_phone': '(718) 996-8808',
#    'distance': 7289.948910947418},
#   {'id': 'KJFosOrLotvQo_rntg0sjA',
#    'alias': 'bricolage-brooklyn',
#    'name': 'Bricolage',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iT9LJUjljyRSfD_Bfgvjbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bricolage-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 464,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67792, 'longitude': -73.97975},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '162 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17182301835',
#    'display_phone': '(718) 230-1835',
#    'distance': 4436.328227240479},
#   {'id': 'OMu9_FqiziCCHD-SsMBUrQ',
#    'alias': 'em-vietnamese-kitchen-brooklyn',
#    'name': 'Em Vietnamese Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/by49XSibBVtPADu7NyfqCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/em-vietnamese-kitchen-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 218,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.60839, 'longitude': -74.00482},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1702 86th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1702 86th St', 'Brooklyn, NY 11214']},
#    'phone': '+17182323888',
#    'display_phone': '(718) 232-3888',
#    'distance': 7377.049325767764},
#   {'id': '7ORTTDLqRMGSXXnsamQ0Bw',
#    'alias': 'banhmigos-brooklyn-2',
#    'name': 'Banhmigos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/j9ogbFZBpB5dc1nnySWWPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/banhmigos-brooklyn-2?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 160,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6741804392653,
#     'longitude': -73.9570099343586},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '636 Park Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['636 Park Pl', 'Brooklyn, NY 11238']},
#    'phone': '+17184839933',
#    'display_phone': '(718) 483-9933',
#    'distance': 2849.39264424073},
#   {'id': '0QrYCr-3dgHfRmvciIlKXQ',
#    'alias': 'pho-86-brooklyn',
#    'name': 'Pho 86',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eER860N--rUtBvCEEYaA2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pho-86-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 21,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.60504, 'longitude': -73.99955},
#    'transactions': [],
#    'location': {'address1': '1944 86th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1944 86th St', 'Brooklyn, NY 11214']},
#    'phone': '+13475875026',
#    'display_phone': '(347) 587-5026',
#    'distance': 7311.6326220985}],
#  'total': 825,
#  'region': {'center': {'longitude': -73.93936157226562,
#    'latitude': 40.652330148320374}}}

# %%
response.json()
# Out:
# {'businesses': [{'id': 'rnioN9LciPxkfKo799QRCQ',
#    'alias': 'u-bar-and-restaurant-brooklyn',
#    'name': 'U Bar & Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7nfJYHonc6q1O8uG4JWvAA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/u-bar-and-restaurant-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 30,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.598165, 'longitude': -73.960569},
#    'transactions': [],
#    'location': {'address1': '1114 Ave U',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11223',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1114 Ave U', 'Brooklyn, NY 11223']},
#    'phone': '+13475876843',
#    'display_phone': '(347) 587-6843',
#    'distance': 6283.193130681312},
#   {'id': 'SSDOkx5enfRH3nsniS_2jA',
#    'alias': '5ive-spice-brooklyn-3',
#    'name': '5ive Spice',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8Yz9iiKDesar5FvWQTIaTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/5ive-spice-brooklyn-3?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 606,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68145923448, 'longitude': -73.9772509779765},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '52 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['52 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17188573483',
#    'display_phone': '(718) 857-3483',
#    'distance': 4550.115551912267},
#   {'id': 'ZLZswviJ0CSX5ZeQFSO2sQ',
#    'alias': 'pho-vietnam-brooklyn',
#    'name': 'Pho Vietnam',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6UFwrMXM63jC6e6SC8o7-Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pho-vietnam-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 291,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.598733, 'longitude': -73.958544},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '1243 Ave U',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11229',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1243 Ave U', 'Brooklyn, NY 11229']},
#    'phone': '+17189982858',
#    'display_phone': '(718) 998-2858',
#    'distance': 6175.689435579791},
#   {'id': 'CPY7tIaJ8XaEEZ9n7xBvkw',
#    'alias': 'banh-mi-place-brooklyn',
#    'name': 'Banh Mi Place',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DFyzdg-CAUatUmROBDqB0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/banh-mi-place-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 233,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6732865, 'longitude': -73.963134},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '824B Washington Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['824B Washington Ave', 'Brooklyn, NY 11238']},
#    'phone': '+17185522660',
#    'display_phone': '(718) 552-2660',
#    'distance': 3074.1870744327484},
#   {'id': 'O-zwQQV8AExgdPoJiqjpDg',
#    'alias': 'ba-xuyen-brooklyn-2',
#    'name': 'Ba Xuyen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0ughD3xXQYDcwvuHzUdj3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ba-xuyen-brooklyn-2?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 653,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.64528, 'longitude': -73.9997099},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '4222 8th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11232',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4222 8th Ave', 'Brooklyn, NY 11232']},
#    'phone': '+17186336601',
#    'display_phone': '(718) 633-6601',
#    'distance': 5149.22835317752},
#   {'id': 'gl9UKHI6G-JhIBjjLFOhYA',
#    'alias': 'high-lúa-vietnamese-kitchen-brooklyn',
#    'name': 'High Lúa Vietnamese Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3KwOwrOJ_DQNb6rO4ItAjw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/high-l%C3%BAa-vietnamese-kitchen-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 127,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71258, 'longitude': -73.96045},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '182 S 2nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['182 S 2nd St', 'Brooklyn, NY 11211']},
#    'phone': '+13478449666',
#    'display_phone': '(347) 844-9666',
#    'distance': 6921.153948197649},
#   {'id': 'R-TRmWuK1nBGRB7iq0XphA',
#    'alias': 'nam-nam-brooklyn-2',
#    'name': 'Nam Nam',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KbrWiKfv_yD5-T5AjI-A3g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nam-nam-brooklyn-2?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 441,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70728, 'longitude': -73.94509},
#    'transactions': ['pickup'],
#    'price': '$',
#    'location': {'address1': '109 Montrose Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['109 Montrose Ave', 'Brooklyn, NY 11206']},
#    'phone': '+17183029200',
#    'display_phone': '(718) 302-9200',
#    'distance': 6130.371931620766},
#   {'id': 'iYFauSnqLxvr4HTY_cIElg',
#    'alias': 'little-mo-brooklyn',
#    'name': 'Little Mo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/f2pS7K-QYKqA97dr9cBmVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-mo-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 312,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69701, 'longitude': -73.93368},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1158 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1158 Myrtle Ave', 'Brooklyn, NY 11221']},
#    'phone': '+19292108100',
#    'display_phone': '(929) 210-8100',
#    'distance': 4991.218644640781},
#   {'id': 'CMm3Xf-9v3QJ4ge20MoEVg',
#    'alias': 'pho-60-brooklyn-8',
#    'name': 'Pho 60',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/CFORdDi1MVSSXrUihQN5Lg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pho-60-brooklyn-8?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 175,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6328610543603,
#     'longitude': -74.0049596875906},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1001 60th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11219',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1001 60th St', 'Brooklyn, NY 11219']},
#    'phone': '+17188857722',
#    'display_phone': '(718) 885-7722',
#    'distance': 5943.045144832211},
#   {'id': 'IoPJ1I0eQn6wnrFAoqFXOw',
#    'alias': 'banhmigos-new-york-2',
#    'name': 'Banhmigos',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/loi0CTRvG34ajwyfeczieQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/banhmigos-new-york-2?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 9,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69111, 'longitude': -73.99184},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '92 Court St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['92 Court St', 'New York, NY 11201']},
#    'phone': '+19293376188',
#    'display_phone': '(929) 337-6188',
#    'distance': 6184.807526230124},
#   {'id': 'V58g7E1AHkuTchTVyLQuYQ',
#    'alias': 'saigon-grill-and-bar-brooklyn-3',
#    'name': 'Saigon Grill & Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/n0P0wybogAiDPrhsXoF0Fg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saigon-grill-and-bar-brooklyn-3?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 201,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.61883, 'longitude': -73.93099},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '4521 Ave N',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11234',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4521 Ave N', 'Brooklyn, NY 11234']},
#    'phone': '+17183388883',
#    'display_phone': '(718) 338-8883',
#    'distance': 3780.4561518574164},
#   {'id': 'EvLkJaWEXTZ8QNBrxOhDsA',
#    'alias': 'bunker-brooklyn',
#    'name': 'Bunker',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vM8KHLsG6Xk-z1IZLdCKmw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bunker-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 712,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7105638, 'longitude': -73.9233984},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '99 Scott Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 Scott Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17183864282',
#    'display_phone': '(718) 386-4282',
#    'distance': 6613.711059246267},
#   {'id': 'rxiY-8y415P7HM68qOlJcw',
#    'alias': 'ha-noi-vietnamese-kitchen-brooklyn',
#    'name': 'Ha Noi Vietnamese Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6OJl8xYpBrJ35gLuaVf9rQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ha-noi-vietnamese-kitchen-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 269,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.66666, 'longitude': -73.9814899},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '448 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11215',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['448 9th St', 'Brooklyn, NY 11215']},
#    'phone': '+17187887755',
#    'display_phone': '(718) 788-7755',
#    'distance': 3893.44633332756},
#   {'id': '3nATnhLyWRvbUGRwK2zdXQ',
#    'alias': 'zen-yai-pho-noodle-bar-brooklyn',
#    'name': 'Zen Yai Pho Noodle Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UlahgYJ0ka9YWRSYx7UgMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zen-yai-pho-noodle-bar-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 55,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.713897, 'longitude': -73.960337},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '208 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['208 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+13478895150',
#    'display_phone': '(347) 889-5150',
#    'distance': 7067.576415905188},
#   {'id': 't4PA7TuIg2TCxBkVuRw7AA',
#    'alias': 'pho-tay-ho-brooklyn',
#    'name': 'Pho Tay Ho',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XxlImvK74ebH_NijaojNgQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pho-tay-ho-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 395,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.600039, 'longitude': -73.990132},
#    'transactions': ['pickup'],
#    'price': '$',
#    'location': {'address1': '2351 86th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2351 86th St', 'Brooklyn, NY 11214']},
#    'phone': '+17184490199',
#    'display_phone': '(718) 449-0199',
#    'distance': 7221.689675413961},
#   {'id': 'FCvWw_e__UfxYusrC99Klw',
#    'alias': 'little-saigon-pearl-brooklyn',
#    'name': 'Little Saigon Pearl',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/gmzHEd-bYy4AwusrWlwIbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-saigon-pearl-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 145,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.599368, 'longitude': -73.9902738},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '9 Bay 35th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Bay 35th St', 'Brooklyn, NY 11214']},
#    'phone': '+17189968808',
#    'display_phone': '(718) 996-8808',
#    'distance': 7289.948910947418},
#   {'id': 'KJFosOrLotvQo_rntg0sjA',
#    'alias': 'bricolage-brooklyn',
#    'name': 'Bricolage',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iT9LJUjljyRSfD_Bfgvjbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bricolage-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 464,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.67792, 'longitude': -73.97975},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '162 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11217',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 5th Ave', 'Brooklyn, NY 11217']},
#    'phone': '+17182301835',
#    'display_phone': '(718) 230-1835',
#    'distance': 4436.328227240479},
#   {'id': 'OMu9_FqiziCCHD-SsMBUrQ',
#    'alias': 'em-vietnamese-kitchen-brooklyn',
#    'name': 'Em Vietnamese Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/by49XSibBVtPADu7NyfqCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/em-vietnamese-kitchen-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 218,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.60839, 'longitude': -74.00482},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1702 86th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1702 86th St', 'Brooklyn, NY 11214']},
#    'phone': '+17182323888',
#    'display_phone': '(718) 232-3888',
#    'distance': 7377.049325767764},
#   {'id': '7ORTTDLqRMGSXXnsamQ0Bw',
#    'alias': 'banhmigos-brooklyn-2',
#    'name': 'Banhmigos',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/j9ogbFZBpB5dc1nnySWWPA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/banhmigos-brooklyn-2?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 160,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.6741804392653,
#     'longitude': -73.9570099343586},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '636 Park Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['636 Park Pl', 'Brooklyn, NY 11238']},
#    'phone': '+17184839933',
#    'display_phone': '(718) 483-9933',
#    'distance': 2849.39264424073},
#   {'id': '0QrYCr-3dgHfRmvciIlKXQ',
#    'alias': 'pho-86-brooklyn',
#    'name': 'Pho 86',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eER860N--rUtBvCEEYaA2w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pho-86-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#    'review_count': 21,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.60504, 'longitude': -73.99955},
#    'transactions': [],
#    'location': {'address1': '1944 86th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11214',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1944 86th St', 'Brooklyn, NY 11214']},
#    'phone': '+13475875026',
#    'display_phone': '(347) 587-5026',
#    'distance': 7311.6326220985}],
#  'total': 825,
#  'region': {'center': {'longitude': -73.93936157226562,
#    'latitude': 40.652330148320374}}}

# %% [markdown]
# Now let's go a bit further and start to preview what's stored in each of the values for these keys.

# %%
data = response.json()

# %%
for key in data.keys():
    print(key)
    value = response.json()[key] #Use standard dictionary formatting
    print(type(value)) #What type is it?
    print('\n\n') #Seperate out data
# Out:
# businesses
# <class 'list'>
#
#
#
# total
# <class 'int'>
#
#
#
# region
# <class 'dict'>

# %% [markdown]
# Let's make sure our data is as expected by looking at a couple of different business by taking a slice of the data.

# %%
data['businesses'][0]
# Out:
# {'id': 'rnioN9LciPxkfKo799QRCQ',
#  'alias': 'u-bar-and-restaurant-brooklyn',
#  'name': 'U Bar & Restaurant',
#  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7nfJYHonc6q1O8uG4JWvAA/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/u-bar-and-restaurant-brooklyn?adjust_creative=NTOFq0hWesFzHYCprBXMFw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=NTOFq0hWesFzHYCprBXMFw',
#  'review_count': 30,
#  'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#  'rating': 4.0,
#  'coordinates': {'latitude': 40.598165, 'longitude': -73.960569},
#  'transactions': [],
#  'location': {'address1': '1114 Ave U',
#   'address2': '',
#   'address3': None,
#   'city': 'Brooklyn',
#   'zip_code': '11223',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['1114 Ave U', 'Brooklyn, NY 11223']},
#  'phone': '+13475876843',
#  'display_phone': '(347) 587-6843',
#  'distance': 6283.193130681312}

# %% [markdown]
# There are a lot of key-value pairs for each business. Many of which we do not care about. Let's create a simple parser of this data that will return a tuple with the name, display_address, and one other data point of your choice.

# %%
business = data['businesses'][0]

# %%
biz_tuple = ('name', 'display_address', 'rating')

# %% [markdown]
# Now that we know how to do this for one business. Let create a function that recieves the list of businesses and returns a list of tuples with the important information.

# %%
businesses = data['businesses']
def parse_data(businesses):
    # create a container to hold our parsed data
    list_biz_tuples = []
    
    # loop through our business and parse each individual business
    for business in businesses:
        biz_tuple = (business['name'], business['location']['display_address'], business['rating'])
#         for display_address in business:
#             listtostr = ' '.join([display_address(elem) for elem in display_address])
        list_biz_tuples.append(biz_tuple)
    return list_biz_tuples
    
    # in the loop, add each individual parsed parsed business to our data container
    
    # return the container with all of the parsed results

# %%
parse_data(businesses)
# Out:
# [('U Bar & Restaurant', ['1114 Ave U', 'Brooklyn, NY 11223'], 4.0),
#  ('5ive Spice', ['52 5th Ave', 'Brooklyn, NY 11217'], 4.0),
#  ('Pho Vietnam', ['1243 Ave U', 'Brooklyn, NY 11229'], 4.0),
#  ('Banh Mi Place', ['824B Washington Ave', 'Brooklyn, NY 11238'], 4.0),
#  ('Ba Xuyen', ['4222 8th Ave', 'Brooklyn, NY 11232'], 4.5),
#  ('High Lúa Vietnamese Kitchen', ['182 S 2nd St', 'Brooklyn, NY 11211'], 4.5),
#  ('Nam Nam', ['109 Montrose Ave', 'Brooklyn, NY 11206'], 4.5),
#  ('Little Mo', ['1158 Myrtle Ave', 'Brooklyn, NY 11221'], 4.0),
#  ('Pho 60', ['1001 60th St', 'Brooklyn, NY 11219'], 4.0),
#  ('Banhmigos', ['92 Court St', 'New York, NY 11201'], 4.0),
#  ('Saigon Grill & Bar', ['4521 Ave N', 'Brooklyn, NY 11234'], 4.5),
#  ('Bunker', ['99 Scott Ave', 'Brooklyn, NY 11237'], 4.0),
#  ('Ha Noi Vietnamese Kitchen', ['448 9th St', 'Brooklyn, NY 11215'], 3.5),
#  ('Zen Yai Pho Noodle Bar', ['208 Grand St', 'Brooklyn, NY 11211'], 4.5),
#  ('Pho Tay Ho', ['2351 86th St', 'Brooklyn, NY 11214'], 3.0),
#  ('Little Saigon Pearl', ['9 Bay 35th St', 'Brooklyn, NY 11214'], 4.0),
#  ('Bricolage', ['162 5th Ave', 'Brooklyn, NY 11217'], 4.0),
#  ('Em Vietnamese Kitchen', ['1702 86th St', 'Brooklyn, NY 11214'], 4.0),
#  ('Banhmigos', ['636 Park Pl', 'Brooklyn, NY 11238'], 3.5),
#  ('Pho 86', ['1944 86th St', 'Brooklyn, NY 11214'], 3.0)]

# %%
# Out:
# <class 'str'>
